# %% [markdown]
# ## CREDIT CARD FRAUD DETECTION MODEL

# %% [markdown]
# 1. Dataset Loading

# %%
import pandas as pd

# %%
data = pd.read_csv('creditcard.csv')

pd.options.display.max_columns = None # for displaying all columns

# %% [markdown]
# 2. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
#  3. Check Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %% [markdown]
# 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %% [markdown]
# 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# 6. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# 7.Feature Scaling and Data Cleaning

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'],axis=1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
284807- 275663
# Out:
# 9144

# %% [markdown]
# 8.  Handling Imbalanced

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unbalanced
#
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction
#
# ----------------------------------------------------
# A dataset is typically considered imbalanced when one class significantly outnumbers the other. For instance, in a binary classification problem, you might have two classes: 0 and 1. If 90% of the instances belong to class 0 and only 10% to class 1, the dataset is highly imbalanced.
#
# Why Imbalanced Datasets Are a Problem ?
#
# * Biased predictions
#
# * Low sensitivity
#
# * Poor generalization
# ----------------------------------------------------------
# Resampling Techniques for Handling Imbalanced Dataset
#
# * Oversampling the Minority Class: This involves increasing the number of samples in the minority class by duplicating them or creating synthetic samples using techniques like SMOTE (Synthetic Minority Over-sampling Technique).
#
# * Undersampling the Majority Class: This technique reduces the number of samples in the majority class, helping balance the dataset. However, it may lead to information loss if too many samples are removed.

# %% [markdown]
# 9. Store Feature Matrix In X And Response (Target) In Vector y

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %% [markdown]
#  10. Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# 11. Handling Imbalanced Dataset

# %% [markdown]
# Undersampling

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape, fraud.shape
# Out:
# ((275190, 30), (473, 30))

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.934529 -0.418971 -0.761239  1.351565 -0.244431  0.177288 -0.531043
# 1 -2.041373  0.270317 -0.620898 -0.443337  1.758701 -0.870012  0.224470
# 2  0.761708 -1.227787  0.788009  0.821022 -1.459512 -0.041333 -0.484106
# 3  1.168776 -0.133684  0.599125  0.857062 -0.571444 -0.138774 -0.293131
# 4  1.235746  0.640995  0.440827  2.277443  0.258567 -0.039740  0.169928
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.169977  1.402795  0.168607 -1.857819 -0.823779 -2.078583  0.223077
# 1  0.275844 -0.264814 -0.962525 -1.270324 -0.091709  0.347645 -0.742770
# 2  0.014483 -0.501246  0.538652 -0.404291  0.236108  0.269726 -0.166773
# 3  0.098879  0.777009 -0.236694 -0.720274  0.061454 -1.026249  0.012193
# 4 -0.096618 -0.806480  0.645516 -1.089794  0.124228  1.033509  0.070476
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# 12. Model Building For UNDERSAMPLING

# %% [markdown]
# * LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9526315789473684

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.979381443298969

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9313725490196079

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9547738693467337

# %% [markdown]
# * PRECISION:
#
# It refers to the proportion of correct positive predictions (True Positives) out of all the positive predictions made by the model (True Positives + False Positives). It is a measure of the accuracy of the positive predictions.
#
# * RECALL:
#
# It is also known as Sensitivity or True Positive Rate where we measures the proportion of actual positive instances that were correctly identified by the model. It is the ratio of True Positives to the total actual positives (True Positives + False Negatives)
#
# * F1 SCORE:
#
# F1 score is a valuable metric in machine learning especially when dealing with imbalanced datasets. By combining precision and recall. F1 score provides a balanced evaluation of a model’s performance.

# %% [markdown]
# * DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9052631578947369

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9117647058823529

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9117647058823529

# %% [markdown]
# * RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9473684210526315

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9893617021276596

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9489795918367347

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})
final_data
# Out:
#   Models        ACC
# 0     LR  95.263158
# 1     DT  90.526316
# 2     RF  94.736842

# %%
import seaborn as sns
sns.barplot(x='Models', y='ACC', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# 13. OVERSAMPLING USING SMOTE

# %%
X = data.drop('Class',axis=1)
y = data['Class']


X.shape,y.shape
# Out:
# ((275663, 29), (275663,))

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# 14. Model For Oversampling

# %% [markdown]
# * LOGISTIC REGRESSION

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9449017042770449

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.973160072707584

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9149682744577569

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9431674428628991

# %% [markdown]
# * DECISION TREE CLASSIFIER

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9982830044696391

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9974950081684516

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.999072777848481

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9982832695993388

# %% [markdown]
# * RANDOM FOREST CLASSIFIER

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9999364075729495

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998727504090166

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999363711561361

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                    ]})


final_data
# Out:
#   Models        ACC
# 0     LR  94.490170
# 1     DT  99.828300
# 2     RF  99.993641

# %%
sns.barplot(x='Models', y='ACC', data=final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %% [markdown]
# 15. Save the Model

# %%
rf1 = RandomForestClassifier()
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1, 'fraud_model.pkl')
# Out:
# ['fraud_model.pkl']

# %%
joblib.dump(sc, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
import joblib
model = joblib.load('fraud_model.pkl')
print(model.n_features_in_)  # shows how many features the model expects
# Out:
# 29
